# %%
from pathlib import Path
import pickle
import warnings

import numpy as np
import pandas as pd

from sqlalchemy import create_engine
from surprise import Dataset, Reader, dump
from tqdm import tqdm

from src.models import cf, evaluate_model
from src.utilities import utilities

tqdm.pandas()
warnings.filterwarnings('ignore')
# Out:
# /Users/jensen/Desktop/recommendation-systems/projects/product-reviews-recommender/.venv/lib/python3.9/site-packages/gensim/similarities/__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %% [markdown]
# # Load Data

# %%
# global variables
DATA_PATH = "data/evaluation"
CATEGORY = "Grocery_and_Gourmet_Food"
# MODEL_PATH = Path(f"models/funk_svd/funk_svd_{CATEGORY}.pkl")

# training parameters
N_EPOCHS = 5
LR_ALL = 0.005
BETA = 0.1

# reproducibility checks
SEED = 42
np.random.seed(42)

train = pd.read_csv(f"{DATA_PATH}/{CATEGORY}_train.csv")

# %%
# checking train dataframe
train.head().append(train.tail())
# Out:
#        index        asin                                              title  \
# 0          0  9742356831                  Mae Ploy Green Curry Paste, 14 oz
# 1          1  9742356831                  Mae Ploy Green Curry Paste, 14 oz
# 2          3  9742356831                  Mae Ploy Green Curry Paste, 14 oz
# 3          4  9742356831                  Mae Ploy Green Curry Paste, 14 oz
# 4          5  9742356831                  Mae Ploy Green Curry Paste, 14 oz
# 47769  77420  B00I33696K  Reese's Miniature Peanut Butter Cups .31oz - 1...
# 47770  77421  B00I33696K  Reese's Miniature Peanut Butter Cups .31oz - 1...
# 47771  77430  B00ID9VSOM  Viva Labs Organic Coconut Sugar: Non-GMO, Low-...
# 47772  77456  B00IRL93SY  Barrie House Kenya Estate - AA Single Cup Caps...
# 47773  77508  B00ISVHJ3Y  Wholesome Sweeteners, Organic Sweet and Lite S...
#
#                                               categories      reviewerID  \
# 0      ['Grocery & Gourmet Food', 'Sauces, Gravies & ...  A23RYWDS884TUL
# 1      ['Grocery & Gourmet Food', 'Sauces, Gravies & ...   A945RBQWGZXCK
# 2      ['Grocery & Gourmet Food', 'Sauces, Gravies & ...  A3AMNY44OP8AOU
# 3      ['Grocery & Gourmet Food', 'Sauces, Gravies & ...  A3IB4CQ2QEJLJ8
# 4      ['Grocery & Gourmet Food', 'Sauces, Gravies & ...   AQA5DF3RWKETQ
# 47769  ['Grocery & Gourmet Food', 'Candy & Chocolate'...  A192LQZWDYPR4U
# 47770  ['Grocery & Gourmet Food', 'Candy & Chocolate'...  A2QKXW3LDQ66P5
# 47771  ['Grocery & Gourmet Food', 'Cooking & Baking',...  A2P3TGJU301KXD
# 47772  ['Grocery & Gourmet Food', 'Beverages', 'Coffe...   AEFE9VDHTQ199
# 47773  ['Grocery & Gourmet Food', 'Cooking & Baking',...  A2AEZQ3DGBBLPR
#
#        overall                                         reviewText  reviewTime  \
# 0          5.0  This curry paste makes a delicious curry.  I j...  2013-05-28
# 1          5.0  I've purchased different curries in the grocer...  2012-09-17
# 2          4.0  I started a new diet restricting all added sug...  2014-01-23
# 3          5.0  So many flavors. I can't begin to tell you how...  2014-04-27
# 4          5.0  I've used this a lot recently in some of my ch...  2012-11-27
# 47769      5.0  Another quality Reese Peanut Butter Cup produc...  2014-02-27
# 47770      5.0  I purchased these for my husband who has every...  2013-02-20
# 47771      5.0  this stuff is INCREDIBILY yummy! SO much bette...  2014-07-15
# 47772      5.0  Very nice aroma, body and taste! Will buy this...  2014-05-24
# 47773      2.0  This is a no go for diabetics according to my ...  2014-06-26
#
#                                      processedReviewText
# 0      curry paste delicious curry fry chicken vegeta...
# 1      purchase different curry grocery store complet...
# 2      start new diet restrict added sugar brand suga...
# 3      flavor begin tell love mae ploy curry ask reci...
# 4      use lot recently chicken dish use lot like spi...
# 47769  quality reese peanut butter cup product great ...
# 47770  purchase husband love reeses valentine day pre...
# 47771  stuff incredibily yummy good regular brown sug...
# 47772  nice aroma body taste buy coffee good coffee a...
# 47773  diabetic accord wife doctor order intention us...

# %% [markdown]
# # Generate N-Recommendations = {10, 25, 30, 45}

# %% [markdown]
# ## Load Test Data

# %%
test = pd.read_csv(f"{DATA_PATH}/{CATEGORY}_test.csv")

# %%
test.head().append(test.tail())
# Out:
#        index        asin                                              title  \
# 0          2  9742356831                  Mae Ploy Green Curry Paste, 14 oz
# 1          8  9742356831                  Mae Ploy Green Curry Paste, 14 oz
# 2         23  B00004S1C5                  Ateco Food Coloring Kit, 6 colors
# 3         31  B00005344V  Traditional Medicinals Organic Breathe Easy Se...
# 4         32  B00005344V  Traditional Medicinals Organic Breathe Easy Se...
# 28001  77519  B00ISVHJ3Y  Wholesome Sweeteners, Organic Sweet and Lite S...
# 28002  77520  B00ISVHJ3Y  Wholesome Sweeteners, Organic Sweet and Lite S...
# 28003  77521  B00ISVHJ3Y  Wholesome Sweeteners, Organic Sweet and Lite S...
# 28004  77522  B00ISVHJ3Y  Wholesome Sweeteners, Organic Sweet and Lite S...
# 28005  77523  B00ISVHJ3Y  Wholesome Sweeteners, Organic Sweet and Lite S...
#
#                                               categories      reviewerID  \
# 0      ['Grocery & Gourmet Food', 'Sauces, Gravies & ...  A1TCSC0YWT82Q0
# 1      ['Grocery & Gourmet Food', 'Sauces, Gravies & ...  A1Z7Y2GMAP9SRY
# 2      ['Grocery & Gourmet Food', 'Cooking & Baking',...  A14YSMLYLJEMET
# 3      ['Grocery & Gourmet Food', 'Beverages', 'Coffe...  A2F488C4PLWGEI
# 4      ['Grocery & Gourmet Food', 'Beverages', 'Coffe...   AO1HXV7DWZZIR
# 28001  ['Grocery & Gourmet Food', 'Cooking & Baking',...  A1WT3TVHANP7ZF
# 28002  ['Grocery & Gourmet Food', 'Cooking & Baking',...  A3NEAETOSXDBOM
# 28003  ['Grocery & Gourmet Food', 'Cooking & Baking',...   AD1ZOPB0BBEHB
# 28004  ['Grocery & Gourmet Food', 'Cooking & Baking',...  A18ECVX2RJ7HUE
# 28005  ['Grocery & Gourmet Food', 'Cooking & Baking',...  A2G04D4QZAXL15
#
#        overall                                         reviewText  reviewTime  \
# 0          5.0  I love ethnic foods and to cook them. I recent...  2013-08-03
# 1          5.0  I like to make my own curry but this is a tast...  2014-06-27
# 2          1.0  This product is no where near natural / organi...  2013-03-29
# 3          5.0  If my wife drinks a cup of this tea when she f...  2014-03-23
# 4          5.0  I don't know about the medicinal aspects of th...  2014-02-06
# 28001      3.0  Hmmm. I really wanted to love this sweetener. ...  2014-07-22
# 28002      5.0  I confess I have a sweet tooth, and love the t...  2014-06-30
# 28003      4.0  It has a little of the stevia aftertaste, but ...  2014-07-17
# 28004      5.0  i love marinade for grilled flank steak or lon...  2014-05-30
# 28005      3.0  I've been using Truvia (a form of stevia) on m...  2014-05-27
#
#                                      processedReviewText
# 0      love ethnic food cook recently purchase produc...
# 1      like curry tasty alternative use base kind dif...
# 2      product near natural organic wish review purch...
# 3      wife drink cup tea feel attack come help avoid...
# 4      know medicinal aspect tea flavor downright scr...
# 28001  hmmm want love sweetener half sugar half stevi...
# 28002  confess sweet tooth love taste sugar recognize...
# 28003  little stevia aftertaste fair compromise able ...
# 28004  love marinade grilled flank steak london broil...
# 28005  use truvia form stevia cereal greek yogurt yea...

# %%
# generating test history
test_user_history = (pd.DataFrame(test.groupby(['reviewerID'])['asin']
                                  .apply(list).reset_index()))

# %%
print(test_user_history)
# Out:
#                   reviewerID  \
# 0      A00177463W0XWB16A9O05
# 1      A022899328A0QROR32DCT
# 2      A068255029AHTHDXZURNU
# 3      A06944662TFWOKKV4GJKX
# 4             A1004703RC79J9
# ...                      ...
# 13274          AZWRZZAMX90VT
# 13275          AZXKAH2DE6C8A
# 13276          AZXON596A1VXC
# 13277          AZYXC63SS008M
# 13278          AZZ5ASC403N74
#
#                                                     asin
# 0                               [B00474OR8G, B00BFM6OAW]
# 1                                           [B00CMQDKES]
# 2                                           [B001FA1K2G]
# 3                                           [B000GFYRHG]
# 4                                           [B003GTR8IO]
# ...                                                  ...
# 13274  [B0007R9L4M, B000CN7BMA, B001EQ5D1K, B002VT3GX...
# 13275   [B000MAK41I, B004X8TJP2, B006H34CUS, B007W14RMM]
# 13276                           [B001EO5S0I, B00271QQ7Q]
# 13277                                       [B0054TWPNC]
# 13278                                       [B00BIEU5PC]
#
# [13279 rows x 2 columns]

# %% [markdown]
# ## Instantiate FunkSVD (Matrix Factorization)

# %%
# instantiating funksvd 
funk_svd = cf.FunkMF(n_epochs=N_EPOCHS, 
                     lr_all=LR_ALL, 
                     reg_all=BETA)

# %%
# fitting to the training data
funk_svd.fit(train)
# Out:
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4

# %%
# %%time
# creating testset for prediction
testset = funk_svd.trainset.build_anti_testset()
# Out:
# CPU times: user 31.8 s, sys: 1.49 s, total: 33.3 s
# Wall time: 33.5 s

# %%
# %%time
# generate candidate times
candidate_items = funk_svd.test(testset)
# Out:
# CPU times: user 6min 53s, sys: 2min 23s, total: 9min 16s
# Wall time: 10min 6s

# %% [markdown]
# ## Save Model
#
# * Not adviced to save model due to long persistence time required to save the model.

# %% [markdown]
# ## Loop through N = {10, 25, 30, 45}

# %%
# generate item popularity
item_popularity = evaluate_model.generate_item_popularity(train)

# %%
# %%time
n_recommendations = {}
for n in [10, 25, 30, 45]:
    # retrieve the top-n items based on similarities
    # top_ns = get_top_n(candidate_items, n)
    top_ns = funk_svd.get_top_n(n)
    # evaluate how well the recommended items predicted the future purchases
    n_recommended_items = (evaluate_model.
                           evaluate_recommendations(model_name = 'FUNK-SVD',
                                                    top_ns = top_ns,
                                                    user_rating_history = test_user_history, 
                                                    item_popularity = item_popularity, 
                                                    n = n,
                                                    mf_based = True))
    # saving the n-value and recommended items
    n_recommendations[n] = (top_ns, n_recommended_items)
# Out:
# The FUNK-SVD has an average recall@10: 0.01355, average novelty@10: 0.85758
# The FUNK-SVD has an average recall@25: 0.02420, average novelty@25: 0.87891
# The FUNK-SVD has an average recall@30: 0.02735, average novelty@30: 0.88282
# The FUNK-SVD has an average recall@45: 0.03659, average novelty@45: 0.89247
# CPU times: user 4min 19s, sys: 2min 7s, total: 6min 27s
# Wall time: 8min 9s

# %% [markdown]
# # Evaluate N-Recommendations

# %% [markdown]
# ## N=10

# %%
top_ns_10 = n_recommendations[10][0]
utilities.retrieve_recommendations(train, top_ns_10, mf_based=True)
# Out:
# For user: A3R3SOV9T2GQUG:
# Purchase History:
#              asin                                              title
# 17110  B001CHFUDC  Coffee People Donut Shop Regular Medium Roast ...
# 20836  B001EO6ESS  Green Mountain Coffee Decaf Dark Magic, 24-Cou...
#
# Recommending:
#
#          asin                                              title
# 0  B000G82L62  Lundberg Family Farms Wild Blend Rice, 16 Ounc...
# 1  B00014JNI0  YS Organic Bee Farms CERTIFIED ORGANIC RAW HON...
# 2  B00DS842HS  Viva Naturals Organic Extra Virgin Coconut Oil...
# 3  B000GAT6NG  Nutiva Organic, Cold-Pressed, Unrefined, Virgi...
# 4  B000EDDS6Q  Bob's Red Mill Old Country Style Muesli Cereal...
# 5  B001PEWJWC  Garbanzo Beans aka Chickpeas or Ceci Beans | N...
# 6  B003OGKCDC  Nature's Way Organic Extra Virgin Coconut Oil-...
# 7  B000HDK0DC  YumEarth Organic Lollipops, Assorted Flavors, ...
# 8  B000Z93FQC               Y.S. Eco Bee Farms Raw Honey - 22 oz
# 9  B000JMAVYO  Spicy World Almonds Whole (Natural and Raw), 4...

# %% [markdown]
# ## N=25

# %%
top_ns_25 = n_recommendations[25][0]
utilities.retrieve_recommendations(train, top_ns_25, mf_based=True)
# Out:
# For user: AT2IQUQOH1W4Q:
# Purchase History:
#              asin                                              title
# 21373  B001EQ4Z96  McCormick Culinary Imitation Banana Extract, 1...
# 29358  B002EY5TTW  Wild Planet, Wild Albacore Tuna, 5-Ounce Cans,...
#
# Recommending:
#
#           asin                                              title
# 0   B00014JNI0  YS Organic Bee Farms CERTIFIED ORGANIC RAW HON...
# 1   B00DS842HS  Viva Naturals Organic Extra Virgin Coconut Oil...
# 2   B001O1Q0NA  The Spice Lab Pink Himalayan Salt - 1 Pound X-...
# 3   B000EDG3UE  Bob's Red Mill Organic Grain Quinoa, 26 Ounce ...
# 4   B000S8593W           Nutiva Hempseeds, Shelled, Pouch 8.00 OZ
# 5   B0001M0Z6Q  Spicy World Peppercorn (Whole)-Black Tellicher...
# 6   B003OGKCDC  Nature's Way Organic Extra Virgin Coconut Oil-...
# 7   B000EDDS6Q  Bob's Red Mill Old Country Style Muesli Cereal...
# 8   B000HDJZWO  Enjoy Life Baking Chocolate, Soy free, Nut fre...
# 9   B000EDK5LM  Bob's Red Mill Vital Wheat Gluten Flour, 22-ou...
# 10  B00271QQ7Q  Coombs Family Farms 100% Pure Organic Maple Sy...
# 11  B000DZDJ0K  Pamela's Products Gluten Free Baking &amp; Pan...
# 12  B000Z93FQC               Y.S. Eco Bee Farms Raw Honey - 22 oz
# 13  B000HDK0DC  YumEarth Organic Lollipops, Assorted Flavors, ...
# 14  B001PEWJWC  Garbanzo Beans aka Chickpeas or Ceci Beans | N...
# 15  B001EO5U3I                     Grocery &amp; Gourmet Food" />
# 16  B000F4DKAI  Twinings of London English Afternoon Black Tea...
# 17  B00338DSQ4      Barilla Spaghetti Pasta, 32 Ounce (Pack of 6)
# 18  B0001CXUHW                   Saf Instant Yeast, 1 Pound Pouch
# 19  B001E5E1WS  Rishi Tea Organic Silver Needle Jasmine Loose ...
# 20  B0054TWQMM         Nutiva Organic White Chia Seeds 12oz2 pack
# 21  B0029XLH4Y  Keurig, Coffee People, Jet Fuel, K-Cup Counts,...
# 22  B000F4D5GC  Let's Do Organic Shredded, Unsweetened Coconut...
# 23  B003VSFELS   Nutiva Organic Chips, Coconut, 1 Pound, 16 Ounce
# 24  B001SB8AZC  Wild Planet Wild Skipjack Tuna (Light Tuna), 5...

# %% [markdown]
# ## N=30

# %%
top_ns_30 = n_recommendations[30][0]
utilities.retrieve_recommendations(train, top_ns_30, mf_based=True)
# Out:
# For user: A1F9Z42CFF9IAY:
# Purchase History:
#              asin                                              title
# 24784  B001M09AZS  Quaker Instant Oatmeal Cinnamon &amp; Spice, 1...
# 33996  B0045Z4JAI  Newman's Own Organics Newman's Special Decaf K...
# 35453  B004FELBH8  Newtons Fruit Thins Fig and Honey, 10.5-Ounce ...
# 37061  B004LA1LKI  Ritz Crackerful Multigrain Crackers, Sharp Che...
# 41144  B005K4Q1T0  Grove Square Hot Cocoa Dark Chocolate, 24 Sing...
# 42190  B005VOOQHS  Kool Aid Peach Mango Sugar Sweetened, 19-Ounce...
# 42541  B0061IUKDM  Higgins &amp; Burke, Green Tea, 20 Count (Pack...
# 43485  B006MONQMC  Vitamin Squeeze Energy Drink, Fruit Punch, 12-...
# 44735  B007JFXWRC  Lipton Herbal Pyramid Tea Bags, Blackberry Van...
# 45014  B007POT6VI         Quaker Instant Oats Variety Pack, 48-Count
# 45594  B008YUL4KI  Lipton Pyramid Tea Bags, Spiced Cinnamon Chai,...
#
# Recommending:
#
#           asin                                              title
# 0   B00014JNI0  YS Organic Bee Farms CERTIFIED ORGANIC RAW HON...
# 1   B0001CXUHW                   Saf Instant Yeast, 1 Pound Pouch
# 2   B000F4DKAI  Twinings of London English Afternoon Black Tea...
# 3   B000G82L62  Lundberg Family Farms Wild Blend Rice, 16 Ounc...
# 4   B00DS842HS  Viva Naturals Organic Extra Virgin Coconut Oil...
# 5   B000EDDS6Q  Bob's Red Mill Old Country Style Muesli Cereal...
# 6   B001PEWJWC  Garbanzo Beans aka Chickpeas or Ceci Beans | N...
# 7   B0001M0Z6Q  Spicy World Peppercorn (Whole)-Black Tellicher...
# 8   B001EO5U3I                     Grocery &amp; Gourmet Food" />
# 9   B000F4D5GC  Let's Do Organic Shredded, Unsweetened Coconut...
# 10  B001NC8HQS  Idahoan Buttery homestyle flavored mashed pota...
# 11  B000HDK0DC  YumEarth Organic Lollipops, Assorted Flavors, ...
# 12  B000Z93FQC               Y.S. Eco Bee Farms Raw Honey - 22 oz
# 13  B0000W0GQQ  Nielsen-Massey Madagascar Bourbon Vanilla Bean...
# 14  B001SB8AZC  Wild Planet Wild Skipjack Tuna (Light Tuna), 5...
# 15  B00338DSQ4      Barilla Spaghetti Pasta, 32 Ounce (Pack of 6)
# 16  B003OGKCDC  Nature's Way Organic Extra Virgin Coconut Oil-...
# 17  B000EDG3UE  Bob's Red Mill Organic Grain Quinoa, 26 Ounce ...
# 18  B0025UCHS6                     Barilla Plus Pasta, 14.5 Ounce
# 19  B001EO6ESS  Green Mountain Coffee Decaf Dark Magic, 24-Cou...
# 20  B0054TWQMM         Nutiva Organic White Chia Seeds 12oz2 pack
# 21  B0029XLH4Y  Keurig, Coffee People, Jet Fuel, K-Cup Counts,...
# 22  B000H7ELTW      Traverse Bay Fruit Dried Cranberries, 4 Pound
# 23  B0025UCI0I  Barilla Whole Grain Spaghetti, 13.25 oz(Pack o...
# 24  B000GFYRHG  Bigelow Constant Comment Tea 20-Count Boxes (P...
# 25  B00017028M              Maldon Sea Salt Flakes, 8.5 ounce Box
# 26  B000WR4SJ0  Simply Organic Italian Seasoning Certified Org...
# 27  B0029JEKAG  Dove Milk Chocolate, Silky Smooth Promises, 9....
# 28  B0025UCHT0                     Barilla Plus Pasta, 14.5 Ounce
# 29  B000HDJZWO  Enjoy Life Baking Chocolate, Soy free, Nut fre...

# %% [markdown]
# ## N=45

# %%
top_ns_45 = n_recommendations[45][0]
utilities.retrieve_recommendations(train, top_ns_45, mf_based=True)
# Out:
# For user: A19XXJ5ZQCMA5B:
# Purchase History:
#              asin                                              title
# 13551  B000YPIL2K  Quaker Instant Grits Flavor Variety, 12-Count ...
# 19001  B001E5E24A   Medaglia D&#39;Oro Instant Espresso Coffee, 2...
#
# Recommending:
#
#           asin                                              title
# 0   B003OGKCDC  Nature's Way Organic Extra Virgin Coconut Oil-...
# 1   B00014JNI0  YS Organic Bee Farms CERTIFIED ORGANIC RAW HON...
# 2   B000Z93FQC               Y.S. Eco Bee Farms Raw Honey - 22 oz
# 3   B0001CXUHW                   Saf Instant Yeast, 1 Pound Pouch
# 4   B0025UCHRC   Barilla Plus Penne Pasta, 14.5 Ounce (Pack of 8)
# 5   B001E5E1WS  Rishi Tea Organic Silver Needle Jasmine Loose ...
# 6   B000HDJZWO  Enjoy Life Baking Chocolate, Soy free, Nut fre...
# 7   B000EDDS6Q  Bob's Red Mill Old Country Style Muesli Cereal...
# 8   B00DS842HS  Viva Naturals Organic Extra Virgin Coconut Oil...
# 9   B000F4D5GC  Let's Do Organic Shredded, Unsweetened Coconut...
# 10  B001O1Q0NA  The Spice Lab Pink Himalayan Salt - 1 Pound X-...
# 11  B00017028M              Maldon Sea Salt Flakes, 8.5 ounce Box
# 12  B000F4DKAI  Twinings of London English Afternoon Black Tea...
# 13  B000DZDJ0K  Pamela's Products Gluten Free Baking &amp; Pan...
# 14  B000FBM54S  Jules Destrooper Butter Waffles, Belgian Vanil...
# 15  B000EICISA       Mae Ploy Thai Yellow Curry Paste - 14 oz jar
# 16  B001L4JH5I  Pamela's Products Gluten-free Bread Mix, 4-Pou...
# 17  B0002YB40O        Ajinomoto - Hon Dashi (Soup Stock) 4.23 Oz.
# 18  B001E5DYEE  Traverse Bay Fruit Dried Cherries, 8 Ounce (Pa...
# 19  B005C3IVN8  Anderson's Pure Maple Syrup, Grade A Very Dark...
# 20  B0029J6QLM         Snickers Dark Chocolate Candy (Pack of 24)
# 21  B000ED7MO0  Bob's Red Mill Sun Dried Raisins Unsulphured, ...
# 22  B0000W0GQQ  Nielsen-Massey Madagascar Bourbon Vanilla Bean...
# 23  B002HQCWYM  Twinings of London English Breakfast Tea K-Cup...
# 24  B001EO5U3I                     Grocery &amp; Gourmet Food" />
# 25  B0021491QM  Ortiz Bonito Del Norte - White Tuna in Olive O...
# 26  B001PEWJWC  Garbanzo Beans aka Chickpeas or Ceci Beans | N...
# 27  B002MO765O  EZ-Sweetz (2.0oz - Liquid Sweetener 800 Servin...
# 28  B001E5E06U   Kashi, Breakfast Cereal, Organic Autumn Wheat...
# 29  B000S8593W           Nutiva Hempseeds, Shelled, Pouch 8.00 OZ
# 30  B005XB5K0G  Starbucks House Blend, K-Cup for Keurig Brewer...
# 31  B000216O16   Authentic Foods Superfine White Rice Flour - 3lb
# 32  B0014EOV9W  Campbell's Condensed Soup, Cream of Chicken, 1...
# 33  B001E50WDA  SPLENDA No Calorie Sweetener Granular, 9.7-Oun...
# 34  B000EDG3UE  Bob's Red Mill Organic Grain Quinoa, 26 Ounce ...
# 35  B001E6EJTW  Town House Crackers, Original, 16-Ounce Boxes ...
# 36  B002RBRY0Y  Lindt LINDOR Dark Chocolate Truffles, Kosher, ...
# 37  B001VNGLEY  Frontier Co-op Organic Mediterranean Oregano L...
# 38  B001EQ5JLE   PG Tips Black Tea, Pyramid Tea Bags, 240-Coun...
# 39  B000E682F0  Celestial Seasonings Sleepytime Echinacea Comp...
# 40  B0001M0Z6Q  Spicy World Peppercorn (Whole)-Black Tellicher...
# 41  B0029XLH4Y  Keurig, Coffee People, Jet Fuel, K-Cup Counts,...
# 42  B000HDI5O8  Farmers Market Organic Pumpkin, 15 Ounce (Pack...
# 43  B001E5E3JY  SweetLeaf Sweet Drops Liquid Stevia Sweetener,...
# 44  B0000IJYK4  Maseca Instant Yellow Corn Masa Flour 4.84lb |...

# %% [markdown]
# # Cross-Analysis for Cold-Start Users (<= 2 Purchased Items)

# %%
cold_start_users = utilities.generate_cold_start_users(train)

# %%
for n in tuple(zip([10, 25, 30, 45], [top_ns_10, top_ns_25, top_ns_30, top_ns_45])):
    cold_start_top_ns = dict(filter(lambda x: x[0] in cold_start_users, n[1].items()))
    # evaluate how well the recommended items predicted the future purchases
    # on cold start users
    n_recommended_items = (evaluate_model.
                           evaluate_recommendations(model_name = 'FUNK-SVD',
                                                    top_ns = cold_start_top_ns,
                                                    user_rating_history = test_user_history, 
                                                    item_popularity = item_popularity, 
                                                    n = n[0],
                                                    mf_based = True))
# Out:
# The FUNK-SVD has an average recall@10: 0.01385, average novelty@10: 0.85747
# The FUNK-SVD has an average recall@25: 0.02515, average novelty@25: 0.87894
# The FUNK-SVD has an average recall@30: 0.02863, average novelty@30: 0.88297
# The FUNK-SVD has an average recall@45: 0.03766, average novelty@45: 0.89262

# %% [markdown]
# # Generating Recommended Items DataFrame

# %%
max_recommendations = (utilities
                       .generate_recommendations_df(
                           train, 
                           n_recommendations, 
                           "FUNK-SVD", mf_based=True))

# %%
max_recommendations
# Out:
#                    reviewerID item_rank        asin algorithm  \
# 0       A00177463W0XWB16A9O05         0  B000EDDS6Q  FUNK-SVD
# 1       A00177463W0XWB16A9O05         1  B00014JNI0  FUNK-SVD
# 2       A00177463W0XWB16A9O05         2  B00DS842HS  FUNK-SVD
# 3       A00177463W0XWB16A9O05         3  B000F4DKAI  FUNK-SVD
# 4       A00177463W0XWB16A9O05         4  B00271OPVU  FUNK-SVD
# ...                       ...       ...         ...       ...
# 602860          AZZ5ASC403N74        40  B001E55ZQO  FUNK-SVD
# 602861          AZZ5ASC403N74        41  B007VCF1QI  FUNK-SVD
# 602862          AZZ5ASC403N74        42  B001J9QBU4  FUNK-SVD
# 602863          AZZ5ASC403N74        43  B001E50WDA  FUNK-SVD
# 602864          AZZ5ASC403N74        44  B000E671ZW  FUNK-SVD
#
#                                                     title
# 0       Bob's Red Mill Old Country Style Muesli Cereal...
# 1       YS Organic Bee Farms CERTIFIED ORGANIC RAW HON...
# 2       Viva Naturals Organic Extra Virgin Coconut Oil...
# 3       Twinings of London English Afternoon Black Tea...
# 4        Coombs Family Farms Maple Syrup, Organic, Gra...
# ...                                                   ...
# 602860  Old Wisconsin Beef Snack Sticks, 7-Ounce Pouch...
# 602861  Enjoy Life Lentil Chips, Soy free, Nut free, G...
# 602862                     Grocery &amp; Gourmet Food" />
# 602863  SPLENDA No Calorie Sweetener Granular, 9.7-Oun...
# 602864  Celestial Seasonings Dessert Tea, Almond Sunse...
#
# [602865 rows x 5 columns]

# %% [markdown]
# # Store in `SQLite` DB

# %%
engine = create_engine("sqlite:///recommender.db", echo=True)

# %%
max_recommendations.to_sql(f"{CATEGORY}", con=engine, if_exists="append")
# Out:
# 2021-09-29 23:31:09,287 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Grocery_and_Gourmet_Food")
# 2021-09-29 23:31:09,293 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-09-29 23:31:09,476 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-09-29 23:31:11,761 INFO sqlalchemy.engine.Engine INSERT INTO "Grocery_and_Gourmet_Food" ("index", "reviewerID", item_rank, asin, algorithm, title) VALUES (?, ?, ?, ?, ?, ?)
# 2021-09-29 23:31:11,761 INFO sqlalchemy.engine.Engine [generated in 1.84224s] ((0, 'A00177463W0XWB16A9O05', 0, 'B000EDDS6Q', 'FUNK-SVD', "Bob's Red Mill Old Country Style Muesli Cereal, 40-ounce (Pack of 4)"), (1, 'A00177463W0XWB16A9O05', 1, 'B00014JNI0', 'FUNK-SVD', 'YS Organic Bee Farms CERTIFIED ORGANIC RAW HONEY 100% CERTIFIED ORGANIC HONEY Raw, Unprocessed, Unpasteurized - Kosher 32oz(pack of 1)'), (2, 'A00177463W0XWB16A9O05', 2, 'B00DS842HS', 'FUNK-SVD', 'Viva Naturals Organic Extra Virgin Coconut Oil, 16 Ounce'), (3, 'A00177463W0XWB16A9O05', 3, 'B000F4DKAI', 'FUNK-SVD', 'Twinings of London English Afternoon Black Tea Bags, 20 Count (Pack of 6)'), (4, 'A00177463W0XWB16A9O05', 4, 'B00271OPVU', 'FUNK-SVD', ' Coombs Family Farms Maple Syrup, Organic, Grade A, Dark Color, Robust Taste, 32 Ounce Jug '), (5, 'A00177463W0XWB16A9O05', 5, 'B00BJH59ZO', 'FUNK-SVD', 'Gratify Gluten Free Sea Salt Sticks Pretzel, 14.1 Ounce - 6 per case.'), (6, 'A00177463W0XWB16A9O05', 6, 'B0029JES6W', 'FUNK-SVD', "M&amp;M'S Almond Chocolate Candy 9.9-Ounce Bag (Pack of 6)"), (7, 'A00177463W0XWB16A9O05', 7, 'B001E5E1WS', 'FUNK-SVD', 'Rishi Tea Organic Silver Needle Jasmine Loose Tea, 1.9-Ounce Tin (Pack of 2)')  ... displaying 10 of 602865 total bound parameter sets ...  (602863, 'AZZ5ASC403N74', 43, 'B001E50WDA', 'FUNK-SVD', 'SPLENDA No Calorie Sweetener Granular, 9.7-Ounce Resealable Bags (Pack of 2)'), (602864, 'AZZ5ASC403N74', 44, 'B000E671ZW', 'FUNK-SVD', 'Celestial Seasonings Dessert Tea, Almond Sunset, Tea Bags, 20-Count Boxes (Pack of 6)'))
# 2021-09-29 23:31:17,392 INFO sqlalchemy.engine.Engine COMMIT
# 2021-09-29 23:31:18,571 INFO sqlalchemy.engine.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2021-09-29 23:31:18,572 INFO sqlalchemy.engine.Engine [raw sql] ()
