# %%
import numpy as np
import pandas as pd

from sqlalchemy import create_engine

# %% [markdown]
# # Load Overall Database

# %%
engine = create_engine("sqlite:///../../recommender.db", echo=True)
demo_engine = create_engine("sqlite:///../../recommender_demo.db", echo=True)

# %% [markdown]
# # Load `Pet_Supplies` Data

# %%
query = f"SELECT * FROM Pet_Supplies;"

# %%
pet_supplies = pd.read_sql(query, engine)
# Out:
# 2021-10-22 20:43:50,090 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("SELECT * FROM Pet_Supplies;")
# 2021-10-22 20:43:50,091 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-10-22 20:43:50,092 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("SELECT * FROM Pet_Supplies;")
# 2021-10-22 20:43:50,093 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-10-22 20:43:50,095 INFO sqlalchemy.engine.Engine SELECT * FROM Pet_Supplies;
# 2021-10-22 20:43:50,095 INFO sqlalchemy.engine.Engine [raw sql] ()

# %%
# check number of rows
pet_supplies.shape
# Out:
# (2279900, 6)

# %%
# check results
pet_supplies.head()
# Out:
#    index             reviewerID  item_rank        asin algorithm  \
# 0      0  A04173782GDZSQ91AJ7OD          0  B001LNSSH2  FUNK-SVD
# 1      1  A04173782GDZSQ91AJ7OD          1  B0002DJONY  FUNK-SVD
# 2      2  A04173782GDZSQ91AJ7OD          2  B000F4AVPA  FUNK-SVD
# 3      3  A04173782GDZSQ91AJ7OD          3  B0002AQKIO  FUNK-SVD
# 4      4  A04173782GDZSQ91AJ7OD          4  B000255NCI  FUNK-SVD
#
#                                                title
# 0  ZYMOX Pet King Brand Otic Pet Ear Treatment wi...
# 1                            Vittles Vault Stackable
# 2                                Chuckit! Ultra Ball
# 3        Fluval Carbon, 100-gram Nylon Bags - 3-Pack
# 4                               API Master Test Kits

# %%
# random sample 100 users
ps_sampled_users = pet_supplies["reviewerID"].sample(100).tolist()

# %%
# sub-select only sampled users for demo
pet_supplies_demo = pet_supplies[pet_supplies.reviewerID.isin(ps_sampled_users)]

# %%
# check dataframe
pet_supplies_demo
# Out:
#           index      reviewerID  item_rank        asin algorithm  \
# 1740       1740  A10LT95KAA2LIV          0  B001LNSSH2  FUNK-SVD
# 1741       1741  A10LT95KAA2LIV          1  B003BYQ1C8  FUNK-SVD
# 1742       1742  A10LT95KAA2LIV          2  B000F4AVPA  FUNK-SVD
# 1743       1743  A10LT95KAA2LIV          3  B000255NCI  FUNK-SVD
# 1744       1744  A10LT95KAA2LIV          4  B0002AS1CC  FUNK-SVD
# ...         ...             ...        ...         ...       ...
# 2277775  379035   AZ6PVGWX6LG6P         15  B0000CEPED    RANDOM
# 2277776  379036   AZ6PVGWX6LG6P         16  B0000CEPDP    RANDOM
# 2277777  379037   AZ6PVGWX6LG6P         17  B0001A9TE2    RANDOM
# 2277778  379038   AZ6PVGWX6LG6P         18  B0001BV0OI    RANDOM
# 2277779  379039   AZ6PVGWX6LG6P         19  B0001ZWZ8O    RANDOM
#
#                                                      title
# 1740     ZYMOX Pet King Brand Otic Pet Ear Treatment wi...
# 1741                               Armarkat Cat Tree Model
# 1742                                   Chuckit! Ultra Ball
# 1743                                  API Master Test Kits
# 1744                    Bergan Turbo Scratcher Accessories
# ...                                                    ...
# 2277775  Nylabone Healthy Edibles Dog Chew Treat Bones ...
# 2277776               Hi-Tor Neo Diet For Cats 5.5-oz cans
# 2277777                   CatStop Ultrasonic Cat Deterrent
# 2277778  Arm &amp; Hammer Super Scoop Clumping Litter, ...
# 2277779     PetSafe Wireless Fence Pet Containment Systems
#
# [11967 rows x 6 columns]

# %%
# save to demo db
pet_supplies_demo.to_sql("Pet_Supplies", con=demo_engine, if_exists="append")
# Out:
# 2021-10-22 20:44:00,118 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Pet_Supplies")
# 2021-10-22 20:44:00,119 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-10-22 20:44:00,120 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("Pet_Supplies")
# 2021-10-22 20:44:00,121 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-10-22 20:44:00,125 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-10-22 20:44:00,126 INFO sqlalchemy.engine.Engine
# CREATE TABLE "Pet_Supplies" (
# 	level_0 BIGINT,
# 	"index" BIGINT,
# 	"reviewerID" TEXT,
# 	item_rank BIGINT,
# 	asin TEXT,
# 	algorithm TEXT,
# 	title TEXT
# )
#
#
# 2021-10-22 20:44:00,128 INFO sqlalchemy.engine.Engine [no key 0.00165s] ()
# 2021-10-22 20:44:00,132 INFO sqlalchemy.engine.Engine CREATE INDEX "ix_Pet_Supplies_level_0" ON "Pet_Supplies" (level_0)
# 2021-10-22 20:44:00,133 INFO sqlalchemy.engine.Engine [no key 0.00168s] ()
# 2021-10-22 20:44:00,136 INFO sqlalchemy.engine.Engine COMMIT
# 2021-10-22 20:44:00,145 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-10-22 20:44:00,212 INFO sqlalchemy.engine.Engine INSERT INTO "Pet_Supplies" (level_0, "index", "reviewerID", item_rank, asin, algorithm, title) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-10-22 20:44:00,214 INFO sqlalchemy.engine.Engine [generated in 0.05316s] ((1740, 1740, 'A10LT95KAA2LIV', 0, 'B001LNSSH2', 'FUNK-SVD', 'ZYMOX Pet King Brand Otic Pet Ear Treatment with Hydrocortisone'), (1741, 1741, 'A10LT95KAA2LIV', 1, 'B003BYQ1C8', 'FUNK-SVD', 'Armarkat Cat Tree Model'), (1742, 1742, 'A10LT95KAA2LIV', 2, 'B000F4AVPA', 'FUNK-SVD', 'Chuckit! Ultra Ball'), (1743, 1743, 'A10LT95KAA2LIV', 3, 'B000255NCI', 'FUNK-SVD', 'API Master Test Kits'), (1744, 1744, 'A10LT95KAA2LIV', 4, 'B0002AS1CC', 'FUNK-SVD', 'Bergan Turbo Scratcher Accessories'), (1745, 1745, 'A10LT95KAA2LIV', 5, 'B003JFRQQ4', 'FUNK-SVD', 'Scaredy Cut Tiny Trim by Small Pet Grooming Safety Scissor - 4.5&quot; Ear, Nose, Face, Paw - for Cats, Dogs, and All Pets'), (1746, 1746, 'A10LT95KAA2LIV', 6, 'B0002DJONY', 'FUNK-SVD', 'Vittles Vault Stackable'), (1747, 1747, 'A10LT95KAA2LIV', 7, 'B0002AQKIO', 'FUNK-SVD', 'Fluval Carbon, 100-gram Nylon Bags - 3-Pack')  ... displaying 10 of 11967 total bound parameter sets ...  (2277778, 379038, 'AZ6PVGWX6LG6P', 18, 'B0001BV0OI', 'RANDOM', 'Arm &amp; Hammer Super Scoop Clumping Litter, Fragrance Free'), (2277779, 379039, 'AZ6PVGWX6LG6P', 19, 'B0001ZWZ8O', 'RANDOM', 'PetSafe Wireless Fence Pet Containment Systems'))
# 2021-10-22 20:44:00,251 INFO sqlalchemy.engine.Engine COMMIT
# 2021-10-22 20:44:00,281 INFO sqlalchemy.engine.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2021-10-22 20:44:00,281 INFO sqlalchemy.engine.Engine [raw sql] ()

# %% [markdown]
# # Load `Grocery_and_Gourmet_Food` Data

# %%
query = f"SELECT * FROM Grocery_and_Gourmet_Food;"

# %%
grocery_gourmet_food = pd.read_sql(query, engine)
# Out:
# 2021-10-22 20:44:00,295 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("SELECT * FROM Grocery_and_Gourmet_Food;")
# 2021-10-22 20:44:00,297 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-10-22 20:44:00,298 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("SELECT * FROM Grocery_and_Gourmet_Food;")
# 2021-10-22 20:44:00,299 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-10-22 20:44:00,301 INFO sqlalchemy.engine.Engine SELECT * FROM Grocery_and_Gourmet_Food;
# 2021-10-22 20:44:00,302 INFO sqlalchemy.engine.Engine [raw sql] ()

# %%
# check number of rows
grocery_gourmet_food.shape
# Out:
# (1607571, 6)

# %%
# check results
grocery_gourmet_food.head()
# Out:
#    index             reviewerID  item_rank        asin algorithm  \
# 0      0  A00177463W0XWB16A9O05          0  B000EDDS6Q  FUNK-SVD
# 1      1  A00177463W0XWB16A9O05          1  B00014JNI0  FUNK-SVD
# 2      2  A00177463W0XWB16A9O05          2  B00DS842HS  FUNK-SVD
# 3      3  A00177463W0XWB16A9O05          3  B000F4DKAI  FUNK-SVD
# 4      4  A00177463W0XWB16A9O05          4  B00271OPVU  FUNK-SVD
#
#                                                title
# 0  Bob's Red Mill Old Country Style Muesli Cereal...
# 1  YS Organic Bee Farms CERTIFIED ORGANIC RAW HON...
# 2  Viva Naturals Organic Extra Virgin Coconut Oil...
# 3  Twinings of London English Afternoon Black Tea...
# 4   Coombs Family Farms Maple Syrup, Organic, Gra...

# %%
# random sample 100 users
# keeping the users we used in our report analysis as well
ggf_sampled_users = grocery_gourmet_food["reviewerID"].sample(99).tolist() + ['A2DSXA1E02C86D']

# %%
# sub-select only sampled users for demo
grocery_gourmet_food_demo = grocery_gourmet_food[grocery_gourmet_food.reviewerID.isin(ggf_sampled_users)]

# %%
# check dataframe
grocery_gourmet_food_demo
# Out:
#           index      reviewerID  item_rank        asin algorithm  \
# 5800       5800  A132ETQPMHQ585          0  B00DS842HS  FUNK-SVD
# 5801       5801  A132ETQPMHQ585          1  B00014JNI0  FUNK-SVD
# 5802       5802  A132ETQPMHQ585          2  B000Z93FQC  FUNK-SVD
# 5803       5803  A132ETQPMHQ585          3  B000EDDS6Q  FUNK-SVD
# 5804       5804  A132ETQPMHQ585          4  B00017028M  FUNK-SVD
# ...         ...             ...        ...         ...       ...
# 1607446  267815   AZWIEXG6P4Y9W         15  B004VLSW86   MOD-ECF
# 1607447  267816   AZWIEXG6P4Y9W         16  B0029JES6W   MOD-ECF
# 1607448  267817   AZWIEXG6P4Y9W         17  B001E50WDA   MOD-ECF
# 1607449  267818   AZWIEXG6P4Y9W         18  B004VLVOJ0   MOD-ECF
# 1607450  267819   AZWIEXG6P4Y9W         19  B005ECLNIM   MOD-ECF
#
#                                                      title
# 5800     Viva Naturals Organic Extra Virgin Coconut Oil...
# 5801     YS Organic Bee Farms CERTIFIED ORGANIC RAW HON...
# 5802                  Y.S. Eco Bee Farms Raw Honey - 22 oz
# 5803     Bob's Red Mill Old Country Style Muesli Cereal...
# 5804                 Maldon Sea Salt Flakes, 8.5 ounce Box
# ...                                                    ...
# 1607446    Bob's Red Mill Navy Beans, 29 Ounce (Pack of 4)
# 1607447  M&amp;M'S Almond Chocolate Candy 9.9-Ounce Bag...
# 1607448  SPLENDA No Calorie Sweetener Granular, 9.7-Oun...
# 1607449  Bob's Red Mill Organic Oats Whole Groats, 29 O...
# 1607450                              True Orange 100 Count
#
# [11996 rows x 6 columns]

# %%
# save to demo db
grocery_gourmet_food_demo.to_sql("Grocery_and_Gourmet_Food", con=demo_engine, if_exists="append")
# Out:
# 2021-10-22 20:44:07,175 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Grocery_and_Gourmet_Food")
# 2021-10-22 20:44:07,175 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-10-22 20:44:07,176 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("Grocery_and_Gourmet_Food")
# 2021-10-22 20:44:07,177 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-10-22 20:44:07,179 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-10-22 20:44:07,180 INFO sqlalchemy.engine.Engine
# CREATE TABLE "Grocery_and_Gourmet_Food" (
# 	level_0 BIGINT,
# 	"index" BIGINT,
# 	"reviewerID" TEXT,
# 	item_rank BIGINT,
# 	asin TEXT,
# 	algorithm TEXT,
# 	title TEXT
# )
#
#
# 2021-10-22 20:44:07,181 INFO sqlalchemy.engine.Engine [no key 0.00067s] ()
# 2021-10-22 20:44:07,184 INFO sqlalchemy.engine.Engine CREATE INDEX "ix_Grocery_and_Gourmet_Food_level_0" ON "Grocery_and_Gourmet_Food" (level_0)
# 2021-10-22 20:44:07,185 INFO sqlalchemy.engine.Engine [no key 0.00100s] ()
# 2021-10-22 20:44:07,187 INFO sqlalchemy.engine.Engine COMMIT
# 2021-10-22 20:44:07,195 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-10-22 20:44:07,245 INFO sqlalchemy.engine.Engine INSERT INTO "Grocery_and_Gourmet_Food" (level_0, "index", "reviewerID", item_rank, asin, algorithm, title) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-10-22 20:44:07,246 INFO sqlalchemy.engine.Engine [generated in 0.04060s] ((5800, 5800, 'A132ETQPMHQ585', 0, 'B00DS842HS', 'FUNK-SVD', 'Viva Naturals Organic Extra Virgin Coconut Oil, 16 Ounce'), (5801, 5801, 'A132ETQPMHQ585', 1, 'B00014JNI0', 'FUNK-SVD', 'YS Organic Bee Farms CERTIFIED ORGANIC RAW HONEY 100% CERTIFIED ORGANIC HONEY Raw, Unprocessed, Unpasteurized - Kosher 32oz(pack of 1)'), (5802, 5802, 'A132ETQPMHQ585', 2, 'B000Z93FQC', 'FUNK-SVD', 'Y.S. Eco Bee Farms Raw Honey - 22 oz'), (5803, 5803, 'A132ETQPMHQ585', 3, 'B000EDDS6Q', 'FUNK-SVD', "Bob's Red Mill Old Country Style Muesli Cereal, 40-ounce (Pack of 4)"), (5804, 5804, 'A132ETQPMHQ585', 4, 'B00017028M', 'FUNK-SVD', 'Maldon Sea Salt Flakes, 8.5 ounce Box'), (5805, 5805, 'A132ETQPMHQ585', 5, 'B001E55ZQO', 'FUNK-SVD', 'Old Wisconsin Beef Snack Sticks, 7-Ounce Pouches (Pack of 6)'), (5806, 5806, 'A132ETQPMHQ585', 6, 'B0001CXUHW', 'FUNK-SVD', 'Saf Instant Yeast, 1 Pound Pouch'), (5807, 5807, 'A132ETQPMHQ585', 7, 'B000HDK0DC', 'FUNK-SVD', 'YumEarth Organic Lollipops, Assorted Flavors, 5 Pound Bag')  ... displaying 10 of 11996 total bound parameter sets ...  (1607449, 267818, 'AZWIEXG6P4Y9W', 18, 'B004VLVOJ0', 'MOD-ECF', "Bob's Red Mill Organic Oats Whole Groats, 29 Ounce (Pack of 4)"), (1607450, 267819, 'AZWIEXG6P4Y9W', 19, 'B005ECLNIM', 'MOD-ECF', 'True Orange 100 Count'))
# 2021-10-22 20:44:07,271 INFO sqlalchemy.engine.Engine COMMIT
# 2021-10-22 20:44:07,284 INFO sqlalchemy.engine.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2021-10-22 20:44:07,285 INFO sqlalchemy.engine.Engine [raw sql] ()
