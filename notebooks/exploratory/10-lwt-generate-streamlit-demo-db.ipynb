# %%
import numpy as np
import pandas as pd

from sqlalchemy import create_engine

# %% [markdown]
# # Load Overall Database

# %%
engine = create_engine("sqlite:///../../recommender.db", echo=True)
demo_engine = create_engine("sqlite:///../../recommender_demo.db", echo=True)

# %% [markdown]
# # Load `Pet_Supplies` Data

# %%
query = f"SELECT * FROM Pet_Supplies;"

# %%
pet_supplies = pd.read_sql(query, engine)
# Out:
# 2021-09-30 19:22:56,910 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("SELECT * FROM Pet_Supplies;")
# 2021-09-30 19:22:56,911 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-09-30 19:22:56,913 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("SELECT * FROM Pet_Supplies;")
# 2021-09-30 19:22:56,914 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-09-30 19:22:56,916 INFO sqlalchemy.engine.Engine SELECT * FROM Pet_Supplies;
# 2021-09-30 19:22:56,917 INFO sqlalchemy.engine.Engine [raw sql] ()

# %%
# check number of rows
pet_supplies.shape
# Out:
# (5086653, 6)

# %%
# check results
pet_supplies.head()
# Out:
#    index             reviewerID  item_rank        asin algorithm  \
# 0      0  A04173782GDZSQ91AJ7OD          0  B00153RC9I     UB-CF
# 1      1  A04173782GDZSQ91AJ7OD          1  B0002YFSDI     UB-CF
# 2      2  A04173782GDZSQ91AJ7OD          2  B0048Z73TY     UB-CF
# 3      3  A04173782GDZSQ91AJ7OD          3  B009MKCJAI     UB-CF
# 4      4  A04173782GDZSQ91AJ7OD          4  B0002ASC1M     UB-CF
#
#                                                title
# 0  Halo Holistic Natural Dry Cat Food for Adult Cats
# 1                     Mendota Products Dog Slip Lead
# 2   DERMagic Shampoo Bar, 3.75 oz, Certified Organic
# 3                                           KONG TUG
# 4  Pureness Heavyweight Large Crock Pet Dish, 52-...

# %%
# random sample 100 users
ps_sampled_users = pet_supplies["reviewerID"].sample(100).tolist()

# %%
# sub-select only sampled users for demo
pet_supplies_demo = pet_supplies[pet_supplies.reviewerID.isin(ps_sampled_users)]

# %%
# check dataframe
pet_supplies_demo
# Out:
#           index      reviewerID  item_rank        asin algorithm  \
# 3358       3358  A10JNHDRWRR7JY          0  B0002ASM94     UB-CF
# 3359       3359  A10JNHDRWRR7JY          1  B00153RC9I     UB-CF
# 3360       3360  A10JNHDRWRR7JY          2  B0002APRKQ     UB-CF
# 3361       3361  A10JNHDRWRR7JY          3  B00078Y3US     UB-CF
# 3362       3362  A10JNHDRWRR7JY          4  B0048Z73TY     UB-CF
# ...         ...             ...        ...         ...       ...
# 5069638  840595   AX7MV147X2W1T         40  B0006L0UGW   MOD-ECF
# 5069639  840596   AX7MV147X2W1T         41  B0006L2OKW   MOD-ECF
# 5069640  840597   AX7MV147X2W1T         42  B0006N9HWI   MOD-ECF
# 5069641  840598   AX7MV147X2W1T         43  B0006NED2W   MOD-ECF
# 5069642  840599   AX7MV147X2W1T         44  B0006Z9RB2   MOD-ECF
#
#                                                      title
# 3358     Nylabone Dura Chew Pooch Pacifier Chew Bone Va...
# 3359     Halo Holistic Natural Dry Cat Food for Adult Cats
# 3360                                     Lee's Net Breeder
# 3361           Multipet Nuts for Knots Ball Medium Dog Toy
# 3362      DERMagic Shampoo Bar, 3.75 oz, Certified Organic
# ...                                                    ...
# 5069638  Herm Sprenger Chrome Plated Ultra-Plus Prong T...
# 5069639              Hartz Dura Play Bacon Scented Dog Toy
# 5069640                 Classic CMI #22000-012C Pet Strobe
# 5069641             Snoozer Console Pet Car Seat Cream Fur
# 5069642  Pet Gear Happy Trails Pet Stroller for Cats/Do...
#
# [26736 rows x 6 columns]

# %%
# save to demo db
pet_supplies_demo.to_sql("Pet_Supplies", con=demo_engine, if_exists="append")
# Out:
# 2021-09-30 19:27:01,360 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Pet_Supplies")
# 2021-09-30 19:27:01,361 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-09-30 19:27:01,362 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("Pet_Supplies")
# 2021-09-30 19:27:01,362 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-09-30 19:27:01,365 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-09-30 19:27:01,366 INFO sqlalchemy.engine.Engine
# CREATE TABLE "Pet_Supplies" (
# 	level_0 BIGINT,
# 	"index" BIGINT,
# 	"reviewerID" TEXT,
# 	item_rank BIGINT,
# 	asin TEXT,
# 	algorithm TEXT,
# 	title TEXT
# )
#
#
# 2021-09-30 19:27:01,367 INFO sqlalchemy.engine.Engine [no key 0.00062s] ()
# 2021-09-30 19:27:01,369 INFO sqlalchemy.engine.Engine CREATE INDEX "ix_Pet_Supplies_level_0" ON "Pet_Supplies" (level_0)
# 2021-09-30 19:27:01,370 INFO sqlalchemy.engine.Engine [no key 0.00076s] ()
# 2021-09-30 19:27:01,371 INFO sqlalchemy.engine.Engine COMMIT
# 2021-09-30 19:27:01,385 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-09-30 19:27:01,504 INFO sqlalchemy.engine.Engine INSERT INTO "Pet_Supplies" (level_0, "index", "reviewerID", item_rank, asin, algorithm, title) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-09-30 19:27:01,504 INFO sqlalchemy.engine.Engine [generated in 0.09756s] ((3358, 3358, 'A10JNHDRWRR7JY', 0, 'B0002ASM94', 'UB-CF', 'Nylabone Dura Chew Pooch Pacifier Chew Bone Value Pack'), (3359, 3359, 'A10JNHDRWRR7JY', 1, 'B00153RC9I', 'UB-CF', 'Halo Holistic Natural Dry Cat Food for Adult Cats'), (3360, 3360, 'A10JNHDRWRR7JY', 2, 'B0002APRKQ', 'UB-CF', "Lee's Net Breeder"), (3361, 3361, 'A10JNHDRWRR7JY', 3, 'B00078Y3US', 'UB-CF', 'Multipet Nuts for Knots Ball Medium Dog Toy'), (3362, 3362, 'A10JNHDRWRR7JY', 4, 'B0048Z73TY', 'UB-CF', 'DERMagic Shampoo Bar, 3.75 oz, Certified Organic'), (3363, 3363, 'A10JNHDRWRR7JY', 5, 'B009MKCJAI', 'UB-CF', 'KONG TUG'), (3364, 3364, 'A10JNHDRWRR7JY', 6, 'B0002ASC1M', 'UB-CF', 'Pureness Heavyweight Large Crock Pet Dish, 52-Ounce, Colors May Vary'), (3365, 3365, 'A10JNHDRWRR7JY', 7, 'B0002AS5PU', 'UB-CF', 'Kaytee CritterTrail Fun-nels Tubes Accessories Value Pack')  ... displaying 10 of 26736 total bound parameter sets ...  (5069641, 840598, 'AX7MV147X2W1T', 43, 'B0006NED2W', 'MOD-ECF', 'Snoozer Console Pet Car Seat Cream Fur'), (5069642, 840599, 'AX7MV147X2W1T', 44, 'B0006Z9RB2', 'MOD-ECF', 'Pet Gear Happy Trails Pet Stroller for Cats/Dogs, Easy One-Hand Fold with Removable Liner, Storage Basket, Mesh Ventilation'))
# 2021-09-30 19:27:01,570 INFO sqlalchemy.engine.Engine COMMIT
# 2021-09-30 19:27:01,602 INFO sqlalchemy.engine.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2021-09-30 19:27:01,603 INFO sqlalchemy.engine.Engine [raw sql] ()

# %% [markdown]
# # Load `Grocery_and_Gourmet_Food` Data

# %%
query = f"SELECT * FROM Grocery_and_Gourmet_Food;"

# %%
grocery_gourmet_food = pd.read_sql(query, engine)
# Out:
# 2021-09-30 19:28:07,427 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("SELECT * FROM Grocery_and_Gourmet_Food;")
# 2021-09-30 19:28:07,428 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-09-30 19:28:07,429 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("SELECT * FROM Grocery_and_Gourmet_Food;")
# 2021-09-30 19:28:07,430 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-09-30 19:28:07,432 INFO sqlalchemy.engine.Engine SELECT * FROM Grocery_and_Gourmet_Food;
# 2021-09-30 19:28:07,433 INFO sqlalchemy.engine.Engine [raw sql] ()

# %%
# check number of rows
grocery_gourmet_food.shape
# Out:
# (3606047, 6)

# %%
# check results
grocery_gourmet_food.head()
# Out:
#    index             reviewerID  item_rank        asin algorithm  \
# 0      0  A00177463W0XWB16A9O05          0  B0000CNU15    RANDOM
# 1      1  A00177463W0XWB16A9O05          1  B0000GHNT0    RANDOM
# 2      2  A00177463W0XWB16A9O05          2  B0000TA3SK    RANDOM
# 3      3  A00177463W0XWB16A9O05          3  B0000W0GQQ    RANDOM
# 4      4  A00177463W0XWB16A9O05          4  B00014JNI0    RANDOM
#
#                                                title
# 0  Lee Kum Kee Chiu Chow Chili Oil net wt. 205g (...
# 1  El Yucateco Chile Habanero Hot Sauce Bottle, R...
# 2  Wright's Natural Hickory Seasoning Liquid Smok...
# 3  Nielsen-Massey Madagascar Bourbon Vanilla Bean...
# 4  YS Organic Bee Farms CERTIFIED ORGANIC RAW HON...

# %%
# random sample 100 users
ggf_sampled_users = grocery_gourmet_food["reviewerID"].sample(100).tolist()

# %%
# sub-select only sampled users for demo
grocery_gourmet_food_demo = grocery_gourmet_food[grocery_gourmet_food.reviewerID.isin(ggf_sampled_users)]

# %%
# check dataframe
grocery_gourmet_food_demo
# Out:
#           index      reviewerID  item_rank        asin algorithm  \
# 13680     13680  A136LRUR0RDH9J          0  B00005344V    RANDOM
# 13681     13681  A136LRUR0RDH9J          1  B0000CDEPD    RANDOM
# 13682     13682  A136LRUR0RDH9J          2  B0000CFPI2    RANDOM
# 13683     13683  A136LRUR0RDH9J          3  B0000CNU15    RANDOM
# 13684     13684  A136LRUR0RDH9J          4  B0000DBN1L    RANDOM
# ...         ...             ...        ...         ...       ...
# 3605367  602185   AZT9OGZODW8VW         40  B003VSFELS  FUNK-SVD
# 3605368  602186   AZT9OGZODW8VW         41  B000F4D5GC  FUNK-SVD
# 3605369  602187   AZT9OGZODW8VW         42  B000EVIDUY  FUNK-SVD
# 3605370  602188   AZT9OGZODW8VW         43  B00017028M  FUNK-SVD
# 3605371  602189   AZT9OGZODW8VW         44  B000CEO6WM  FUNK-SVD
#
#                                                      title
# 13680    Traditional Medicinals Organic Breathe Easy Se...
# 13681        Rodelle Organic Pure Vanilla Extract, 4-Ounce
# 13682                        BJ-6 3-Pack Jerky Spice Works
# 13683    Lee Kum Kee Chiu Chow Chili Oil net wt. 205g (...
# 13684                 Tazo Organic Chai, 24 Tea Bags 2.3oz
# ...                                                    ...
# 3605367   Nutiva Organic Chips, Coconut, 1 Pound, 16 Ounce
# 3605368  Let's Do Organic Shredded, Unsweetened Coconut...
# 3605369  The Gluten-Free Pantry Double Chocolate Browni...
# 3605370              Maldon Sea Salt Flakes, 8.5 ounce Box
# 3605371  Gloria Jeans K-Cup Butter Toffee Coffee K-Cup ...
#
# [26952 rows x 6 columns]

# %%
# save to demo db
grocery_gourmet_food_demo.to_sql("Grocery_and_Gourmet_Food", con=demo_engine, if_exists="append")
# Out:
# 2021-09-30 19:29:25,394 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Grocery_and_Gourmet_Food")
# 2021-09-30 19:29:25,394 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-09-30 19:29:25,396 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("Grocery_and_Gourmet_Food")
# 2021-09-30 19:29:25,396 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-09-30 19:29:25,398 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-09-30 19:29:25,399 INFO sqlalchemy.engine.Engine
# CREATE TABLE "Grocery_and_Gourmet_Food" (
# 	level_0 BIGINT,
# 	"index" BIGINT,
# 	"reviewerID" TEXT,
# 	item_rank BIGINT,
# 	asin TEXT,
# 	algorithm TEXT,
# 	title TEXT
# )
#
#
# 2021-09-30 19:29:25,400 INFO sqlalchemy.engine.Engine [no key 0.00057s] ()
# 2021-09-30 19:29:25,402 INFO sqlalchemy.engine.Engine CREATE INDEX "ix_Grocery_and_Gourmet_Food_level_0" ON "Grocery_and_Gourmet_Food" (level_0)
# 2021-09-30 19:29:25,403 INFO sqlalchemy.engine.Engine [no key 0.00082s] ()
# 2021-09-30 19:29:25,404 INFO sqlalchemy.engine.Engine COMMIT
# 2021-09-30 19:29:25,420 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-09-30 19:29:25,542 INFO sqlalchemy.engine.Engine INSERT INTO "Grocery_and_Gourmet_Food" (level_0, "index", "reviewerID", item_rank, asin, algorithm, title) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-09-30 19:29:25,543 INFO sqlalchemy.engine.Engine [generated in 0.10180s] ((13680, 13680, 'A136LRUR0RDH9J', 0, 'B00005344V', 'RANDOM', 'Traditional Medicinals Organic Breathe Easy Seasonal Tea, 16 Tea Bags (Pack of 6)'), (13681, 13681, 'A136LRUR0RDH9J', 1, 'B0000CDEPD', 'RANDOM', 'Rodelle Organic Pure Vanilla Extract, 4-Ounce'), (13682, 13682, 'A136LRUR0RDH9J', 2, 'B0000CFPI2', 'RANDOM', 'BJ-6 3-Pack Jerky Spice Works'), (13683, 13683, 'A136LRUR0RDH9J', 3, 'B0000CNU15', 'RANDOM', 'Lee Kum Kee Chiu Chow Chili Oil net wt. 205g (7.2oz)'), (13684, 13684, 'A136LRUR0RDH9J', 4, 'B0000DBN1L', 'RANDOM', 'Tazo Organic Chai, 24 Tea Bags 2.3oz'), (13685, 13685, 'A136LRUR0RDH9J', 5, 'B0000DID5R', 'RANDOM', "Dave's Original Insanity Hot Sauce - 5oz"), (13686, 13686, 'A136LRUR0RDH9J', 6, 'B0000E5JIU', 'RANDOM', 'Cafe Du Monde Coffee Chicory, 15 Ounce Ground'), (13687, 13687, 'A136LRUR0RDH9J', 7, 'B0000GHNT0', 'RANDOM', 'El Yucateco Chile Habanero Hot Sauce Bottle, Red, 8 Ounce')  ... displaying 10 of 26952 total bound parameter sets ...  (3605370, 602188, 'AZT9OGZODW8VW', 43, 'B00017028M', 'FUNK-SVD', 'Maldon Sea Salt Flakes, 8.5 ounce Box'), (3605371, 602189, 'AZT9OGZODW8VW', 44, 'B000CEO6WM', 'FUNK-SVD', 'Gloria Jeans K-Cup Butter Toffee Coffee K-Cup 18 K-cups'))
# 2021-09-30 19:29:25,607 INFO sqlalchemy.engine.Engine COMMIT
# 2021-09-30 19:29:25,631 INFO sqlalchemy.engine.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2021-09-30 19:29:25,631 INFO sqlalchemy.engine.Engine [raw sql] ()
